# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics
from sklearn import preprocessing
from sklearn.linear_model import RidgeCV
from sklearn import tree
from sklearn.cross_validation import cross_val_score
from sklearn.grid_search import GridSearchCV


pd.set_option('display.float_format', lambda x: '%.3f' % x)

xl = pd.ExcelFile("Project_Data.xlsx")
xl.sheet_names
df = xl.parse("Sheet1")

# %%
df.head(2)
df.describe()
print df.corr()
# Out:
#                              ASX Lit Share  ASX Dark Share  ASX On Market  \
# ASX Lit Share                        1.000           0.093          0.956
# ASX Dark Share                       0.093           1.000          0.125
# ASX On Market                        0.956           0.125          1.000
# ASX Continous Share                  0.903           0.074          0.849
# ASX Lit                              0.146          -0.201          0.109
# Chi-X Lit                           -0.580          -0.224         -0.584
# ASX Centre Point                    -0.190           0.093         -0.184
# Chi-X Dark                          -0.112          -0.139         -0.330
# Reported to ASX                      0.165          -0.063          0.156
# Reported to Chi-X                   -0.046          -0.058         -0.088
# Market                               0.067          -0.176          0.027
# Lit + Dark                           0.956           0.124          1.000
# Lit                                  1.000           0.093          0.956
# Reports                              0.172           0.033          0.199
# CP Share                             0.001           0.251          0.267
# Row                                 -0.478          -0.163         -0.433
# Lit Trading - Vanilla               -0.050          -0.245         -0.098
# Trade Registration                   0.150          -0.074          0.143
# Block Discovery                      0.363          -0.053          0.359
# Undisclosed                          0.074           0.063          0.055
# CentrePoint                         -0.189           0.092         -0.185
# Icebergs                            -0.112           0.090         -0.052
# Pref                                -0.077           0.042         -0.098
# UCP                                 -0.176          -0.155         -0.154
# CXA Market                          -0.513          -0.221         -0.569
# Specials                             0.047          -0.010          0.010
# NBBO Trade Report                   -0.202          -0.241         -0.222
# Portfolio Specials                  -0.086          -0.028         -0.105
# Late Trades                         -0.080          -0.036         -0.075
# Broker Pref                          0.030          -0.022         -0.085
# 20-Day Realised SPI Vol             -0.163          -0.354         -0.196
# MOC                                  0.030          -0.102         -0.003
# Spread Differrential                -0.467           0.220         -0.424
# NBBO Trade Report.1                 -0.096          -0.820         -0.065
# %Sweep of Lit                       -0.509           0.250         -0.426
# Index Rebalance                      0.106          -0.004          0.121
# ASX Lit Share (20 MA)                0.794           0.112          0.745
# ASX Dark Share (20 MA)               0.073           0.948          0.091
# ASX On Market.1                      0.759           0.137          0.765
# ASX Continous Share (20 MA)          0.766           0.074          0.704
# Number of Customer Meetings         -0.045          -0.070         -0.082
# Average Meetings                    -0.073          -0.103         -0.104
#
#                              ASX Continous Share  ASX Lit  Chi-X Lit  \
# ASX Lit Share                              0.903    0.146     -0.580
# ASX Dark Share                             0.074   -0.201     -0.224
# ASX On Market                              0.849    0.109     -0.584
# ASX Continous Share                        1.000   -0.043     -0.634
# ASX Lit                                   -0.043    1.000      0.700
# Chi-X Lit                                 -0.634    0.700      1.000
# ASX Centre Point                          -0.261    0.605      0.646
# Chi-X Dark                                -0.143    0.608      0.594
# Reported to ASX                            0.080    0.319      0.142
# Reported to Chi-X                         -0.095    0.378      0.358
# Market                                    -0.099    0.928      0.708
# Lit + Dark                                 0.849    0.109     -0.584
# Lit                                        0.903    0.146     -0.580
# Reports                                    0.151   -0.032     -0.158
# CP Share                                  -0.016   -0.196     -0.167
# Row                                       -0.568    0.328      0.603
# Lit Trading - Vanilla                     -0.043    0.883      0.787
# Trade Registration                         0.054    0.362      0.187
# Block Discovery                           -0.027    0.738      0.274
# Undisclosed                                0.074    0.028     -0.029
# CentrePoint                               -0.258    0.602      0.642
# Icebergs                                  -0.163    0.296      0.315
# Pref                                      -0.097    0.268      0.280
# UCP                                       -0.350    0.634      0.636
# CXA Market                                -0.566    0.733      0.981
# Specials                                   0.002    0.313      0.229
# NBBO Trade Report                         -0.259    0.631      0.677
# Portfolio Specials                        -0.097    0.105      0.162
# Late Trades                               -0.121    0.140      0.173
# Broker Pref                                0.033    0.078      0.050
# 20-Day Realised SPI Vol                   -0.157    0.257      0.333
# MOC                                       -0.028    0.149      0.092
# Spread Differrential                      -0.543    0.099      0.405
# NBBO Trade Report.1                       -0.094    0.387      0.390
# %Sweep of Lit                             -0.575    0.187      0.520
# Index Rebalance                           -0.025    0.192      0.044
# ASX Lit Share (20 MA)                      0.813   -0.090     -0.630
# ASX Dark Share (20 MA)                     0.056   -0.270     -0.268
# ASX On Market.1                            0.767   -0.126     -0.637
# ASX Continous Share (20 MA)                0.844   -0.113     -0.616
# Number of Customer Meetings               -0.037    0.128      0.141
# Average Meetings                          -0.054    0.070      0.118
#
#                              ASX Centre Point  Chi-X Dark  Reported to ASX  \
# ASX Lit Share                          -0.190      -0.112            0.165
# ASX Dark Share                          0.093      -0.139           -0.063
# ASX On Market                          -0.184      -0.330            0.156
# ASX Continous Share                    -0.261      -0.143            0.080
# ASX Lit                                 0.605       0.608            0.319
# Chi-X Lit                               0.646       0.594            0.142
# ASX Centre Point                        1.000       0.566            0.257
# Chi-X Dark                              0.566       1.000            0.186
# Reported to ASX                         0.257       0.186            1.000
# Reported to Chi-X                       0.440       0.389            0.292
# Market                                  0.686       0.637            0.569
# Lit + Dark                             -0.188      -0.332            0.155
# Lit                                    -0.190      -0.112            0.165
# Reports                                -0.079      -0.137            0.513
# CP Share                                0.180      -0.677            0.022
# Row                                     0.454       0.235           -0.105
# Lit Trading - Vanilla                   0.628       0.654            0.240
# Trade Registration                      0.290       0.210            0.997
# Block Discovery                         0.311       0.280            0.289
# Undisclosed                            -0.011       0.041            0.206
# CentrePoint                             0.995       0.574            0.254
# Icebergs                                0.361       0.080            0.142
# Pref                                    0.441       0.348            0.103
# UCP                                     0.485       0.346            0.119
# CXA Market                              0.677       0.737            0.163
# Specials                                0.347       0.310            0.287
# NBBO Trade Report                       0.665       0.522            0.237
# Portfolio Specials                      0.158       0.151            0.091
# Late Trades                             0.193       0.116            0.070
# Broker Pref                             0.088       0.354            0.114
# 20-Day Realised SPI Vol                -0.135       0.159           -0.093
# MOC                                     0.013       0.148            0.018
# Spread Differrential                    0.392       0.105            0.104
# NBBO Trade Report.1                     0.326       0.188            0.257
# %Sweep of Lit                           0.437       0.056           -0.004
# Index Rebalance                         0.048       0.009            0.092
# ASX Lit Share (20 MA)                  -0.340      -0.180            0.065
# ASX Dark Share (20 MA)                  0.024      -0.153           -0.063
# ASX On Market.1                        -0.307      -0.322            0.061
# ASX Continous Share (20 MA)            -0.355      -0.150            0.071
# Number of Customer Meetings             0.063       0.166            0.124
# Average Meetings                        0.008       0.123           -0.064
#
#                              Reported to Chi-X        ...         \
# ASX Lit Share                           -0.046        ...
# ASX Dark Share                          -0.058        ...
# ASX On Market                           -0.088        ...
# ASX Continous Share                     -0.095        ...
# ASX Lit                                  0.378        ...
# Chi-X Lit                                0.358        ...
# ASX Centre Point                         0.440        ...
# Chi-X Dark                               0.389        ...
# Reported to ASX                          0.292        ...
# Reported to Chi-X                        1.000        ...
# Market                                   0.598        ...
# Lit + Dark                              -0.088        ...
# Lit                                     -0.046        ...
# Reports                                 -0.501        ...
# CP Share                                -0.097        ...
# Row                                      0.236        ...
# Lit Trading - Vanilla                    0.374        ...
# Trade Registration                       0.307        ...
# Block Discovery                          0.214        ...
# Undisclosed                              0.251        ...
# CentrePoint                              0.433        ...
# Icebergs                                 0.147        ...
# Pref                                     0.151        ...
# UCP                                      0.245        ...
# CXA Market                               0.393        ...
# Specials                                 0.827        ...
# NBBO Trade Report                        0.482        ...
# Portfolio Specials                       0.630        ...
# Late Trades                              0.168        ...
# Broker Pref                              0.121        ...
# 20-Day Realised SPI Vol                 -0.028        ...
# MOC                                      0.048        ...
# Spread Differrential                     0.115        ...
# NBBO Trade Report.1                      0.200        ...
# %Sweep of Lit                            0.128        ...
# Index Rebalance                          0.030        ...
# ASX Lit Share (20 MA)                   -0.138        ...
# ASX Dark Share (20 MA)                  -0.071        ...
# ASX On Market.1                         -0.160        ...
# ASX Continous Share (20 MA)             -0.126        ...
# Number of Customer Meetings              0.102        ...
# Average Meetings                         0.051        ...
#
#                              Spread Differrential  NBBO Trade Report.1  \
# ASX Lit Share                              -0.467               -0.096
# ASX Dark Share                              0.220               -0.820
# ASX On Market                              -0.424               -0.065
# ASX Continous Share                        -0.543               -0.094
# ASX Lit                                     0.099                0.387
# Chi-X Lit                                   0.405                0.390
# ASX Centre Point                            0.392                0.326
# Chi-X Dark                                  0.105                0.188
# Reported to ASX                             0.104                0.257
# Reported to Chi-X                           0.115                0.200
# Market                                      0.178                0.420
# Lit + Dark                                 -0.426               -0.066
# Lit                                        -0.467               -0.096
# Reports                                     0.086                0.077
# CP Share                                    0.228                0.077
# Row                                         0.455                0.179
# Lit Trading - Vanilla                       0.089                0.440
# Trade Registration                          0.124                0.272
# Block Discovery                             0.068                0.147
# Undisclosed                                 0.014               -0.072
# CentrePoint                                 0.390                0.325
# Icebergs                                    0.206                0.098
# Pref                                        0.167                0.149
# UCP                                         0.306                0.250
# CXA Market                                  0.367                0.372
# Specials                                    0.071                0.136
# NBBO Trade Report                           0.241                0.494
# Portfolio Specials                          0.046                0.050
# Late Trades                                 0.103                0.111
# Broker Pref                                -0.054               -0.006
# 20-Day Realised SPI Vol                    -0.201                0.146
# MOC                                        -0.062                0.058
# Spread Differrential                        1.000                0.269
# NBBO Trade Report.1                         0.269                1.000
# %Sweep of Lit                               0.438                0.313
# Index Rebalance                             0.047                0.008
# ASX Lit Share (20 MA)                      -0.499               -0.173
# ASX Dark Share (20 MA)                      0.271               -0.796
# ASX On Market.1                            -0.462               -0.142
# ASX Continous Share (20 MA)                -0.541               -0.134
# Number of Customer Meetings                 0.035                0.037
# Average Meetings                            0.055                0.038
#
#                              %Sweep of Lit  Index Rebalance  \
# ASX Lit Share                       -0.509            0.106
# ASX Dark Share                       0.250           -0.004
# ASX On Market                       -0.426            0.121
# ASX Continous Share                 -0.575           -0.025
# ASX Lit                              0.187            0.192
# Chi-X Lit                            0.520            0.044
# ASX Centre Point                     0.437            0.048
# Chi-X Dark                           0.056            0.009
# Reported to ASX                     -0.004            0.092
# Reported to Chi-X                    0.128            0.030
# Market                               0.222            0.163
# Lit + Dark                          -0.428            0.121
# Lit                                 -0.509            0.106
# Reports                             -0.097            0.053
# CP Share                             0.305            0.027
# Row                                  0.967            0.074
# Lit Trading - Vanilla                0.200            0.037
# Trade Registration                   0.035            0.103
# Block Discovery                      0.084            0.332
# Undisclosed                         -0.030           -0.011
# CentrePoint                          0.435            0.047
# Icebergs                             0.301            0.104
# Pref                                 0.191            0.015
# UCP                                  0.567            0.158
# CXA Market                           0.454            0.039
# Specials                             0.090            0.019
# NBBO Trade Report                    0.357            0.023
# Portfolio Specials                   0.008            0.028
# Late Trades                          0.167           -0.013
# Broker Pref                         -0.133           -0.032
# 20-Day Realised SPI Vol              0.163            0.011
# MOC                                 -0.013            0.079
# Spread Differrential                 0.438            0.047
# NBBO Trade Report.1                  0.313            0.008
# %Sweep of Lit                        1.000            0.027
# Index Rebalance                      0.027            1.000
# ASX Lit Share (20 MA)               -0.608            0.049
# ASX Dark Share (20 MA)               0.230           -0.026
# ASX On Market.1                     -0.521            0.067
# ASX Continous Share (20 MA)         -0.662           -0.032
# Number of Customer Meetings         -0.119           -0.015
# Average Meetings                    -0.109            0.031
#
#                              ASX Lit Share (20 MA)  ASX Dark Share (20 MA)  \
# ASX Lit Share                                0.794                   0.073
# ASX Dark Share                               0.112                   0.948
# ASX On Market                                0.745                   0.091
# ASX Continous Share                          0.813                   0.056
# ASX Lit                                     -0.090                  -0.270
# Chi-X Lit                                   -0.630                  -0.268
# ASX Centre Point                            -0.340                   0.024
# Chi-X Dark                                  -0.180                  -0.153
# Reported to ASX                              0.065                  -0.063
# Reported to Chi-X                           -0.138                  -0.071
# Market                                      -0.149                  -0.234
# Lit + Dark                                   0.745                   0.090
# Lit                                          0.794                   0.073
# Reports                                      0.140                   0.059
# CP Share                                    -0.042                   0.213
# Row                                         -0.624                  -0.245
# Lit Trading - Vanilla                       -0.172                  -0.317
# Trade Registration                           0.038                  -0.079
# Block Discovery                              0.063                  -0.089
# Undisclosed                                  0.061                   0.089
# CentrePoint                                 -0.333                   0.021
# Icebergs                                    -0.176                   0.051
# Pref                                        -0.107                  -0.022
# UCP                                         -0.361                  -0.228
# CXA Market                                  -0.574                  -0.262
# Specials                                    -0.033                  -0.017
# NBBO Trade Report                           -0.322                  -0.250
# Portfolio Specials                          -0.115                  -0.042
# Late Trades                                 -0.115                  -0.039
# Broker Pref                                  0.072                   0.014
# 20-Day Realised SPI Vol                     -0.195                  -0.402
# MOC                                         -0.011                  -0.101
# Spread Differrential                        -0.499                   0.271
# NBBO Trade Report.1                         -0.173                  -0.796
# %Sweep of Lit                               -0.608                   0.230
# Index Rebalance                              0.049                  -0.026
# ASX Lit Share (20 MA)                        1.000                   0.103
# ASX Dark Share (20 MA)                       0.103                   1.000
# ASX On Market.1                              0.965                   0.129
# ASX Continous Share (20 MA)                  0.960                   0.073
# Number of Customer Meetings                 -0.080                  -0.091
# Average Meetings                            -0.036                  -0.108
#
#                              ASX On Market.1  ASX Continous Share (20 MA)  \
# ASX Lit Share                          0.759                        0.766
# ASX Dark Share                         0.137                        0.074
# ASX On Market                          0.765                        0.704
# ASX Continous Share                    0.767                        0.844
# ASX Lit                               -0.126                       -0.113
# Chi-X Lit                             -0.637                       -0.616
# ASX Centre Point                      -0.307                       -0.355
# Chi-X Dark                            -0.322                       -0.150
# Reported to ASX                        0.061                        0.071
# Reported to Chi-X                     -0.160                       -0.126
# Market                                -0.180                       -0.159
# Lit + Dark                             0.765                        0.704
# Lit                                    0.759                        0.766
# Reports                                0.153                        0.149
# CP Share                               0.146                       -0.086
# Row                                   -0.572                       -0.689
# Lit Trading - Vanilla                 -0.218                       -0.129
# Trade Registration                     0.036                        0.039
# Block Discovery                        0.058                       -0.042
# Undisclosed                            0.055                        0.071
# CentrePoint                           -0.305                       -0.348
# Icebergs                              -0.108                       -0.196
# Pref                                  -0.129                       -0.113
# UCP                                   -0.332                       -0.431
# CXA Market                            -0.613                       -0.555
# Specials                              -0.050                       -0.024
# NBBO Trade Report                     -0.331                       -0.311
# Portfolio Specials                    -0.131                       -0.108
# Late Trades                           -0.105                       -0.125
# Broker Pref                            0.004                        0.082
# 20-Day Realised SPI Vol               -0.242                       -0.171
# MOC                                   -0.048                       -0.020
# Spread Differrential                  -0.462                       -0.541
# NBBO Trade Report.1                   -0.142                       -0.134
# %Sweep of Lit                         -0.521                       -0.662
# Index Rebalance                        0.067                       -0.032
# ASX Lit Share (20 MA)                  0.965                        0.960
# ASX Dark Share (20 MA)                 0.129                        0.073
# ASX On Market.1                        1.000                        0.911
# ASX Continous Share (20 MA)            0.911                        1.000
# Number of Customer Meetings           -0.120                       -0.054
# Average Meetings                      -0.076                       -0.040
#
#                              Number of Customer Meetings  Average Meetings
# ASX Lit Share                                     -0.045            -0.073
# ASX Dark Share                                    -0.070            -0.103
# ASX On Market                                     -0.082            -0.104
# ASX Continous Share                               -0.037            -0.054
# ASX Lit                                            0.128             0.070
# Chi-X Lit                                          0.141             0.118
# ASX Centre Point                                   0.063             0.008
# Chi-X Dark                                         0.166             0.123
# Reported to ASX                                    0.124            -0.064
# Reported to Chi-X                                  0.102             0.051
# Market                                             0.157             0.052
# Lit + Dark                                        -0.082            -0.103
# Lit                                               -0.045            -0.073
# Reports                                            0.004            -0.097
# CP Share                                          -0.140            -0.138
# Row                                                0.059             0.073
# Lit Trading - Vanilla                              0.154             0.106
# Trade Registration                                 0.128            -0.058
# Block Discovery                                    0.033            -0.011
# Undisclosed                                        0.084            -0.016
# CentrePoint                                        0.068             0.011
# Icebergs                                          -0.005            -0.054
# Pref                                               0.082             0.029
# UCP                                                0.063             0.079
# CXA Market                                         0.158             0.128
# Specials                                           0.092             0.046
# NBBO Trade Report                                  0.152             0.118
# Portfolio Specials                                 0.026             0.001
# Late Trades                                       -0.005             0.005
# Broker Pref                                        0.046             0.036
# 20-Day Realised SPI Vol                            0.141             0.090
# MOC                                               -0.034            -0.032
# Spread Differrential                               0.035             0.055
# NBBO Trade Report.1                                0.037             0.038
# %Sweep of Lit                                     -0.119            -0.109
# Index Rebalance                                   -0.015             0.031
# ASX Lit Share (20 MA)                             -0.080            -0.036
# ASX Dark Share (20 MA)                            -0.091            -0.108
# ASX On Market.1                                   -0.120            -0.076
# ASX Continous Share (20 MA)                       -0.054            -0.040
# Number of Customer Meetings                        1.000             0.125
# Average Meetings                                   0.125             1.000
#
# [42 rows x 42 columns]

# %%
# Project, bring in the file for analysis
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics
from sklearn import preprocessing
from sklearn.linear_model import RidgeCV
from sklearn import tree
from sklearn.cross_validation import cross_val_score
from sklearn.grid_search import GridSearchCV


pd.set_option('display.float_format', lambda x: '%.3f' % x)

xl = pd.ExcelFile("Project_Data.xlsx")
xl.sheet_names
df = xl.parse("Sheet1")

#preview of the raw data and return the column names
df.head()
df.columns
# examine to see if there are any null rows
df.isnull().sum()
#there are rows with null data, let us remove these rows
df = df.dropna()
# we have 547 rows of data left, enough for the regression. the dataframe has been cleaned.
df.count()

#drop columns which have the dates
df = df.drop('Date', axis=1)
df = df.drop('Date.1', axis=1)

df.columns
#The data is all in differrent units: percentages, raw numbers, $'s, basis points. 
#If we want to analyse the relative effects of each independent variable on the dependent variables, 
#we'll need to normalise all the data.
# Out:
# Index([u'ASX Lit Share', u'ASX Dark Share', u'ASX On Market',
#        u'ASX Continous Share', u'ASX Lit', u'Chi-X Lit', u'ASX Centre Point',
#        u'Chi-X Dark', u'Reported to ASX', u'Reported to Chi-X', u'Market',
#        u'Lit + Dark', u'Lit', u'Reports', u'CP Share', u'Row',
#        u'Lit Trading - Vanilla', u'Trade Registration', u'Block Discovery',
#        u'Undisclosed', u'CentrePoint', u'Icebergs', u'Pref', u'UCP',
#        u'CXA Market', u'Specials', u'NBBO Trade Report', u'Portfolio Specials',
#        u'Late Trades', u'Broker Pref', u'20-Day Realised SPI Vol', u'MOC',
#        u'Spread Differrential', u'NBBO Trade Report.1', u'%Sweep of Lit',
#        u'Index Rebalance', u'ASX Lit Share (20 MA)', u'ASX Dark Share (20 MA)',
#        u'ASX On Market.1', u'ASX Continous Share (20 MA)',
#        u'Number of Customer Meetings', u'Average Meetings'],
#       dtype='object')

# %%
# the first regression we will look at is for the ASX Lit Market Share. For this, we will focus on the following columns of our raw dataset

#'ASX Lit Share', 'Lit Trading - Vanilla', 'Block Discovery', 'Undisclosed', 'Icebergs', 'Late Trades', '20-Day Realised SPI Vol', 'MOC', 'Spread Differrential', '%Sweep of Lit', 'Index Rebalance', u'ASX Lit Share (20 MA)', 'Average Meetings'  

dfLitShare = df[['ASX Lit Share', 'Chi-X Lit','ASX Centre Point',
       'Chi-X Dark', 'Reported to ASX', 'Reported to Chi-X',
       'Lit Trading - Vanilla', 'Block Discovery',
       'Undisclosed', 'CentrePoint', 'Icebergs', 'Pref', 'UCP',
       'Late Trades', 'Broker Pref', '20-Day Realised SPI Vol', 'MOC',
       'Spread Differrential', 'NBBO Trade Report.1', '%Sweep of Lit',
       'Index Rebalance', 'ASX Dark Share (20 MA)']]
#['ASX Lit Share', 'Lit Trading - Vanilla', 'Block Discovery', '20-Day Realised SPI Vol', 'Spread Differrential', '%Sweep of Lit', 'Index Rebalance', u'ASX Lit Share (20 MA)']]
dfLitShare

#The data is all in differrent units: percentages, raw numbers, $'s, basis points. 
#If we want to analyse the relative effects of each independent variable on the dependent variables, 
#we'll need to normalise all the data.

std_scale = preprocessing.StandardScaler().fit(dfLitShare)
dfLitShare_std = std_scale.transform(dfLitShare)

ColumnNames = ['ASXLitShare', 'Chi-X Lit','ASX Centre Point',
       'Chi-X Dark', 'Reported to ASX', 'Reported to Chi-X',
       'Lit Trading - Vanilla', 'Block Discovery',
       'Undisclosed', 'CentrePoint', 'Icebergs', 'Pref', 'UCP',
       'Late Trades', 'Broker Pref', '20-Day Realised SPI Vol', 'MOC',
       'Spread Differrential', 'NBBO Trade Report.1', '%Sweep of Lit',
       'Index Rebalance', 'ASX Dark Share (20 MA)']

dfLitShare_std = pd.DataFrame(dfLitShare_std, columns = ColumnNames) 
dfLitShare_std

#none of the independent variables look extremely correllated so we donot have to drop any independent variables
dfLitShare_std.corr()

#plot the data to see how it looks
#pd.scatter_matrix(dfLitShare_std, figsize=(15,15))
#plt.show()

#dfLitShare_std.describe()

#let us start the regression. We have chosen Lasso Ridge & Decision Trees for our regression. For those features which are
#irrellevant, we want the coefficients to be 0 rather than very close to zero like ridge regression

X = dfLitShare_std.iloc[:, 1:] #selection of columns, all the columns except the last one.
y = dfLitShare_std.iloc[:,0]


from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)


#use LassoCV to select best alpha, 100 partitions of the data

from sklearn.linear_model import LassoCV
alpha_range = 0.01**np.arange(-3, 3)
lascv = LassoCV(normalize=True, alphas=alpha_range, cv =50)
lascv.fit(X_train, y_train)
lascv.alpha_
lascv.coef_
preds = lascv.predict(X_test)
#print lascv.coef_
print 'RMSE (Lasso CV reg.) =', np.sqrt(metrics.mean_squared_error(y_test, preds))
print ('')
print pd.DataFrame(zip(X_train.columns, lascv.coef_)).sort_values(by=1, ascending=False)
print ('')

#use RidgeCV to select best alpha, 100 partitions of the data

alpha_range = 10.**np.arange(-3, 3)
#CV = indicates cross validation
rregcv = RidgeCV(normalize=True, scoring='mean_squared_error', alphas=alpha_range, cv =50)
rregcv.fit(X_train, y_train)
#print rregcv.coef_
rregcv.alpha_
preds = rregcv.predict(X_test)
print 'RMSE (Ridge CV reg.) =', np.sqrt(metrics.mean_squared_error(y_test, preds))
print ('')
print pd.DataFrame(zip(X_train.columns, rregcv.coef_)).sort_values(by=1, ascending=False)
print ('')


#Decision Tree

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)
rtree = tree.DecisionTreeRegressor()
rtree.fit(X_train, y_train)
scores = cross_val_score(rtree, X, y, cv=50, scoring='mean_squared_error')
mse_scores = scores


print 'RMSE (Decision Tree) =', mse_scores.mean()
print ('')
features = X_train.columns.tolist()
print pd.DataFrame(zip(features, rtree.feature_importances_)).sort_values(by=1, ascending=False)
print ('')


#'ASX Lit Share', 'ASX Dark Share', 'ASX On Market',
#       'ASX Continous Share', 'ASX Lit', 'Chi-X Lit', 'ASX Centre Point',
#       'Chi-X Dark', 'Reported to ASX', 'Reported to Chi-X', 'Market',
#       'Lit + Dark', 'Lit', 'Reports', 'CP Share', 'Row',
#       'Lit Trading - Vanilla', 'Trade Registration', 'Block Discovery',
#       'Undisclosed', 'CentrePoint', 'Icebergs', 'Pref', 'UCP',
#       'CXA Market', 'Specials', 'NBBO Trade Report', 'Portfolio Specials',
#       'Late Trades', 'Broker Pref', '20-Day Realised SPI Vol', 'MOC',
#       'Spread Differrential', 'NBBO Trade Report.1', '%Sweep of Lit',
#       'Index Rebalance', 'ASX Lit Share (20 MA)', 'ASX Dark Share (20 MA)'
# Out:
# RMSE (Lasso CV reg.) = 0.262733381705
#
#                           0      1
# 5     Lit Trading - Vanilla  0.894
# 6           Block Discovery  0.438
# 20   ASX Dark Share (20 MA)  0.061
# 11                      UCP  0.027
# 14  20-Day Realised SPI Vol  0.023
# 17      NBBO Trade Report.1  0.022
# 4         Reported to Chi-X  0.015
# 12              Late Trades  0.006
# 1          ASX Centre Point  0.000
# 13              Broker Pref  0.000
# 10                     Pref -0.000
# 8               CentrePoint  0.000
# 3           Reported to ASX -0.000
# 15                      MOC -0.000
# 2                Chi-X Dark -0.002
# 9                  Icebergs -0.008
# 7               Undisclosed -0.016
# 19          Index Rebalance -0.017
# 18            %Sweep of Lit -0.032
# 16     Spread Differrential -0.057
# 0                 Chi-X Lit -1.355
#
# RMSE (Ridge CV reg.) = 0.26320617935
#
#                           0      1
# 5     Lit Trading - Vanilla  0.885
# 6           Block Discovery  0.439
# 20   ASX Dark Share (20 MA)  0.069
# 11                      UCP  0.031
# 14  20-Day Realised SPI Vol  0.030
# 17      NBBO Trade Report.1  0.026
# 4         Reported to Chi-X  0.018
# 12              Late Trades  0.008
# 13              Broker Pref  0.007
# 1          ASX Centre Point  0.002
# 8               CentrePoint  0.002
# 15                      MOC -0.002
# 10                     Pref -0.002
# 3           Reported to ASX -0.003
# 2                Chi-X Dark -0.011
# 9                  Icebergs -0.012
# 7               Undisclosed -0.019
# 19          Index Rebalance -0.019
# 18            %Sweep of Lit -0.044
# 16     Spread Differrential -0.060
# 0                 Chi-X Lit -1.342
#
# RMSE (Decision Tree) = -0.396762393693
#
#                           0     1
# 6           Block Discovery 0.298
# 18            %Sweep of Lit 0.270
# 16     Spread Differrential 0.156
# 0                 Chi-X Lit 0.122
# 5     Lit Trading - Vanilla 0.034
# 10                     Pref 0.018
# 13              Broker Pref 0.014
# 9                  Icebergs 0.014
# 7               Undisclosed 0.011
# 12              Late Trades 0.010
# 3           Reported to ASX 0.010
# 14  20-Day Realised SPI Vol 0.010
# 4         Reported to Chi-X 0.008
# 2                Chi-X Dark 0.007
# 11                      UCP 0.006
# 15                      MOC 0.004
# 1          ASX Centre Point 0.003
# 20   ASX Dark Share (20 MA) 0.002
# 17      NBBO Trade Report.1 0.002
# 8               CentrePoint 0.001
# 19          Index Rebalance 0.000
