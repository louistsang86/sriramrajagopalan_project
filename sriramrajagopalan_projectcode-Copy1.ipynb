# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics
from sklearn import preprocessing
from sklearn.linear_model import RidgeCV
from sklearn import tree
from sklearn.cross_validation import cross_val_score
from sklearn.grid_search import GridSearchCV


pd.set_option('display.float_format', lambda x: '%.3f' % x)

xl = pd.ExcelFile("Project_Data.xlsx")
xl.sheet_names
df = xl.parse("Sheet1")

# %%
df.head(2)
df.describe()
print df.corr()
# Out:
#                              ASX Lit Share  ASX Dark Share  ASX On Market  \
# ASX Lit Share                        1.000           0.093          0.956
# ASX Dark Share                       0.093           1.000          0.125
# ASX On Market                        0.956           0.125          1.000
# ASX Continous Share                  0.903           0.074          0.849
# ASX Lit                              0.146          -0.201          0.109
# Chi-X Lit                           -0.580          -0.224         -0.584
# ASX Centre Point                    -0.190           0.093         -0.184
# Chi-X Dark                          -0.112          -0.139         -0.330
# Reported to ASX                      0.165          -0.063          0.156
# Reported to Chi-X                   -0.046          -0.058         -0.088
# Market                               0.067          -0.176          0.027
# Lit + Dark                           0.956           0.124          1.000
# Lit                                  1.000           0.093          0.956
# Reports                              0.172           0.033          0.199
# CP Share                             0.001           0.251          0.267
# Row                                 -0.478          -0.163         -0.433
# Lit Trading - Vanilla               -0.050          -0.245         -0.098
# Trade Registration                   0.150          -0.074          0.143
# Block Discovery                      0.363          -0.053          0.359
# Undisclosed                          0.074           0.063          0.055
# CentrePoint                         -0.189           0.092         -0.185
# Icebergs                            -0.112           0.090         -0.052
# Pref                                -0.077           0.042         -0.098
# UCP                                 -0.176          -0.155         -0.154
# CXA Market                          -0.513          -0.221         -0.569
# Specials                             0.047          -0.010          0.010
# NBBO Trade Report                   -0.202          -0.241         -0.222
# Portfolio Specials                  -0.086          -0.028         -0.105
# Late Trades                         -0.080          -0.036         -0.075
# Broker Pref                          0.030          -0.022         -0.085
# 20-Day Realised SPI Vol             -0.163          -0.354         -0.196
# MOC                                  0.030          -0.102         -0.003
# Spread Differrential                -0.467           0.220         -0.424
# NBBO Trade Report.1                 -0.096          -0.820         -0.065
# %Sweep of Lit                       -0.509           0.250         -0.426
# Index Rebalance                      0.106          -0.004          0.121
# ASX Lit Share (20 MA)                0.637           0.125          0.578
# ASX Dark Share (20 MA)               0.068           0.889          0.078
# ASX On Market.1                      0.608           0.141          0.590
# ASX Continous Share (20 MA)          0.645           0.077          0.573
# Number of Customer Meetings         -0.045          -0.070         -0.082
# Average Meetings                    -0.066          -0.292         -0.135
# Sensitive Announcments               0.018           0.037          0.042
#
#                              ASX Continous Share  ASX Lit  Chi-X Lit  \
# ASX Lit Share                              0.903    0.146     -0.580
# ASX Dark Share                             0.074   -0.201     -0.224
# ASX On Market                              0.849    0.109     -0.584
# ASX Continous Share                        1.000   -0.043     -0.634
# ASX Lit                                   -0.043    1.000      0.700
# Chi-X Lit                                 -0.634    0.700      1.000
# ASX Centre Point                          -0.261    0.605      0.646
# Chi-X Dark                                -0.143    0.608      0.594
# Reported to ASX                            0.080    0.319      0.142
# Reported to Chi-X                         -0.095    0.378      0.358
# Market                                    -0.099    0.928      0.708
# Lit + Dark                                 0.849    0.109     -0.584
# Lit                                        0.903    0.146     -0.580
# Reports                                    0.151   -0.032     -0.158
# CP Share                                  -0.016   -0.196     -0.167
# Row                                       -0.568    0.328      0.603
# Lit Trading - Vanilla                     -0.043    0.883      0.787
# Trade Registration                         0.054    0.362      0.187
# Block Discovery                           -0.027    0.738      0.274
# Undisclosed                                0.074    0.028     -0.029
# CentrePoint                               -0.258    0.602      0.642
# Icebergs                                  -0.163    0.296      0.315
# Pref                                      -0.097    0.268      0.280
# UCP                                       -0.350    0.634      0.636
# CXA Market                                -0.566    0.733      0.981
# Specials                                   0.002    0.313      0.229
# NBBO Trade Report                         -0.259    0.631      0.677
# Portfolio Specials                        -0.097    0.105      0.162
# Late Trades                               -0.121    0.140      0.173
# Broker Pref                                0.033    0.078      0.050
# 20-Day Realised SPI Vol                   -0.157    0.257      0.333
# MOC                                       -0.028    0.149      0.092
# Spread Differrential                      -0.543    0.099      0.405
# NBBO Trade Report.1                       -0.094    0.387      0.390
# %Sweep of Lit                             -0.575    0.187      0.520
# Index Rebalance                           -0.025    0.192      0.044
# ASX Lit Share (20 MA)                      0.711   -0.214     -0.614
# ASX Dark Share (20 MA)                     0.056   -0.281     -0.271
# ASX On Market.1                            0.675   -0.256     -0.627
# ASX Continous Share (20 MA)                0.725   -0.183     -0.594
# Number of Customer Meetings               -0.037    0.128      0.141
# Average Meetings                          -0.068    0.192      0.196
# Sensitive Announcments                    -0.035    0.112      0.084
#
#                              ASX Centre Point  Chi-X Dark  Reported to ASX  \
# ASX Lit Share                          -0.190      -0.112            0.165
# ASX Dark Share                          0.093      -0.139           -0.063
# ASX On Market                          -0.184      -0.330            0.156
# ASX Continous Share                    -0.261      -0.143            0.080
# ASX Lit                                 0.605       0.608            0.319
# Chi-X Lit                               0.646       0.594            0.142
# ASX Centre Point                        1.000       0.566            0.257
# Chi-X Dark                              0.566       1.000            0.186
# Reported to ASX                         0.257       0.186            1.000
# Reported to Chi-X                       0.440       0.389            0.292
# Market                                  0.686       0.637            0.569
# Lit + Dark                             -0.188      -0.332            0.155
# Lit                                    -0.190      -0.112            0.165
# Reports                                -0.079      -0.137            0.513
# CP Share                                0.180      -0.677            0.022
# Row                                     0.454       0.235           -0.105
# Lit Trading - Vanilla                   0.628       0.654            0.240
# Trade Registration                      0.290       0.210            0.997
# Block Discovery                         0.311       0.280            0.289
# Undisclosed                            -0.011       0.041            0.206
# CentrePoint                             0.995       0.574            0.254
# Icebergs                                0.361       0.080            0.142
# Pref                                    0.441       0.348            0.103
# UCP                                     0.485       0.346            0.119
# CXA Market                              0.677       0.737            0.163
# Specials                                0.347       0.310            0.287
# NBBO Trade Report                       0.665       0.522            0.237
# Portfolio Specials                      0.158       0.151            0.091
# Late Trades                             0.193       0.116            0.070
# Broker Pref                             0.088       0.354            0.114
# 20-Day Realised SPI Vol                -0.135       0.159           -0.093
# MOC                                     0.013       0.148            0.018
# Spread Differrential                    0.392       0.105            0.104
# NBBO Trade Report.1                     0.326       0.188            0.257
# %Sweep of Lit                           0.437       0.056           -0.004
# Index Rebalance                         0.048       0.009            0.092
# ASX Lit Share (20 MA)                  -0.386      -0.171            0.011
# ASX Dark Share (20 MA)                  0.006      -0.147           -0.062
# ASX On Market.1                        -0.343      -0.282            0.011
# ASX Continous Share (20 MA)            -0.388      -0.129            0.044
# Number of Customer Meetings             0.063       0.166            0.124
# Average Meetings                        0.002       0.268           -0.025
# Sensitive Announcments                  0.074      -0.001            0.075
#
#                              Reported to Chi-X           ...            \
# ASX Lit Share                           -0.046           ...
# ASX Dark Share                          -0.058           ...
# ASX On Market                           -0.088           ...
# ASX Continous Share                     -0.095           ...
# ASX Lit                                  0.378           ...
# Chi-X Lit                                0.358           ...
# ASX Centre Point                         0.440           ...
# Chi-X Dark                               0.389           ...
# Reported to ASX                          0.292           ...
# Reported to Chi-X                        1.000           ...
# Market                                   0.598           ...
# Lit + Dark                              -0.088           ...
# Lit                                     -0.046           ...
# Reports                                 -0.501           ...
# CP Share                                -0.097           ...
# Row                                      0.236           ...
# Lit Trading - Vanilla                    0.374           ...
# Trade Registration                       0.307           ...
# Block Discovery                          0.214           ...
# Undisclosed                              0.251           ...
# CentrePoint                              0.433           ...
# Icebergs                                 0.147           ...
# Pref                                     0.151           ...
# UCP                                      0.245           ...
# CXA Market                               0.393           ...
# Specials                                 0.827           ...
# NBBO Trade Report                        0.482           ...
# Portfolio Specials                       0.630           ...
# Late Trades                              0.168           ...
# Broker Pref                              0.121           ...
# 20-Day Realised SPI Vol                 -0.028           ...
# MOC                                      0.048           ...
# Spread Differrential                     0.115           ...
# NBBO Trade Report.1                      0.200           ...
# %Sweep of Lit                            0.128           ...
# Index Rebalance                          0.030           ...
# ASX Lit Share (20 MA)                   -0.176           ...
# ASX Dark Share (20 MA)                  -0.057           ...
# ASX On Market.1                         -0.194           ...
# ASX Continous Share (20 MA)             -0.151           ...
# Number of Customer Meetings              0.102           ...
# Average Meetings                         0.169           ...
# Sensitive Announcments                   0.048           ...
#
#                              NBBO Trade Report.1  %Sweep of Lit  \
# ASX Lit Share                             -0.096         -0.509
# ASX Dark Share                            -0.820          0.250
# ASX On Market                             -0.065         -0.426
# ASX Continous Share                       -0.094         -0.575
# ASX Lit                                    0.387          0.187
# Chi-X Lit                                  0.390          0.520
# ASX Centre Point                           0.326          0.437
# Chi-X Dark                                 0.188          0.056
# Reported to ASX                            0.257         -0.004
# Reported to Chi-X                          0.200          0.128
# Market                                     0.420          0.222
# Lit + Dark                                -0.066         -0.428
# Lit                                       -0.096         -0.509
# Reports                                    0.077         -0.097
# CP Share                                   0.077          0.305
# Row                                        0.179          0.967
# Lit Trading - Vanilla                      0.440          0.200
# Trade Registration                         0.272          0.035
# Block Discovery                            0.147          0.084
# Undisclosed                               -0.072         -0.030
# CentrePoint                                0.325          0.435
# Icebergs                                   0.098          0.301
# Pref                                       0.149          0.191
# UCP                                        0.250          0.567
# CXA Market                                 0.372          0.454
# Specials                                   0.136          0.090
# NBBO Trade Report                          0.494          0.357
# Portfolio Specials                         0.050          0.008
# Late Trades                                0.111          0.167
# Broker Pref                               -0.006         -0.133
# 20-Day Realised SPI Vol                    0.146          0.163
# MOC                                        0.058         -0.013
# Spread Differrential                       0.269          0.438
# NBBO Trade Report.1                        1.000          0.313
# %Sweep of Lit                              0.313          1.000
# Index Rebalance                            0.008          0.027
# ASX Lit Share (20 MA)                     -0.215         -0.641
# ASX Dark Share (20 MA)                    -0.760          0.125
# ASX On Market.1                           -0.172         -0.555
# ASX Continous Share (20 MA)               -0.161         -0.688
# Number of Customer Meetings                0.037         -0.119
# Average Meetings                           0.108         -0.329
# Sensitive Announcments                     0.023          0.048
#
#                              Index Rebalance  ASX Lit Share (20 MA)  \
# ASX Lit Share                          0.106                  0.637
# ASX Dark Share                        -0.004                  0.125
# ASX On Market                          0.121                  0.578
# ASX Continous Share                   -0.025                  0.711
# ASX Lit                                0.192                 -0.214
# Chi-X Lit                              0.044                 -0.614
# ASX Centre Point                       0.048                 -0.386
# Chi-X Dark                             0.009                 -0.171
# Reported to ASX                        0.092                  0.011
# Reported to Chi-X                      0.030                 -0.176
# Market                                 0.163                 -0.255
# Lit + Dark                             0.121                  0.577
# Lit                                    0.106                  0.637
# Reports                                0.053                  0.120
# CP Share                               0.027                 -0.096
# Row                                    0.074                 -0.658
# Lit Trading - Vanilla                  0.037                 -0.229
# Trade Registration                     0.103                 -0.023
# Block Discovery                        0.332                 -0.098
# Undisclosed                           -0.011                  0.034
# CentrePoint                            0.047                 -0.376
# Icebergs                               0.104                 -0.217
# Pref                                   0.015                 -0.098
# UCP                                    0.158                 -0.461
# CXA Market                             0.039                 -0.559
# Specials                               0.019                 -0.070
# NBBO Trade Report                      0.023                 -0.355
# Portfolio Specials                     0.028                 -0.130
# Late Trades                           -0.013                 -0.118
# Broker Pref                           -0.032                  0.096
# 20-Day Realised SPI Vol                0.011                 -0.178
# MOC                                    0.079                 -0.012
# Spread Differrential                   0.047                 -0.489
# NBBO Trade Report.1                    0.008                 -0.215
# %Sweep of Lit                          0.027                 -0.641
# Index Rebalance                        1.000                 -0.039
# ASX Lit Share (20 MA)                 -0.039                  1.000
# ASX Dark Share (20 MA)                -0.035                  0.117
# ASX On Market.1                       -0.033                  0.965
# ASX Continous Share (20 MA)           -0.051                  0.976
# Number of Customer Meetings           -0.015                 -0.076
# Average Meetings                       0.046                 -0.142
# Sensitive Announcments                -0.029                 -0.104
#
#                              ASX Dark Share (20 MA)  ASX On Market.1  \
# ASX Lit Share                                 0.068            0.608
# ASX Dark Share                                0.889            0.141
# ASX On Market                                 0.078            0.590
# ASX Continous Share                           0.056            0.675
# ASX Lit                                      -0.281           -0.256
# Chi-X Lit                                    -0.271           -0.627
# ASX Centre Point                              0.006           -0.343
# Chi-X Dark                                   -0.147           -0.282
# Reported to ASX                              -0.062            0.011
# Reported to Chi-X                            -0.057           -0.194
# Market                                       -0.240           -0.287
# Lit + Dark                                    0.077            0.589
# Lit                                           0.068            0.608
# Reports                                       0.044            0.136
# CP Share                                      0.186            0.066
# Row                                          -0.243           -0.614
# Lit Trading - Vanilla                        -0.322           -0.276
# Trade Registration                           -0.079           -0.021
# Block Discovery                              -0.103           -0.114
# Undisclosed                                   0.079            0.013
# CentrePoint                                   0.003           -0.337
# Icebergs                                      0.043           -0.154
# Pref                                         -0.027           -0.113
# UCP                                          -0.236           -0.445
# CXA Market                                   -0.264           -0.596
# Specials                                     -0.021           -0.089
# NBBO Trade Report                            -0.240           -0.361
# Portfolio Specials                           -0.013           -0.137
# Late Trades                                  -0.042           -0.103
# Broker Pref                                   0.022            0.041
# 20-Day Realised SPI Vol                      -0.404           -0.232
# MOC                                          -0.101           -0.057
# Spread Differrential                          0.261           -0.456
# NBBO Trade Report.1                          -0.760           -0.172
# %Sweep of Lit                                 0.125           -0.555
# Index Rebalance                              -0.035           -0.033
# ASX Lit Share (20 MA)                         0.117            0.965
# ASX Dark Share (20 MA)                        1.000            0.135
# ASX On Market.1                               0.135            1.000
# ASX Continous Share (20 MA)                   0.079            0.930
# Number of Customer Meetings                  -0.081           -0.130
# Average Meetings                             -0.255           -0.254
# Sensitive Announcments                        0.022           -0.096
#
#                              ASX Continous Share (20 MA)  \
# ASX Lit Share                                      0.645
# ASX Dark Share                                     0.077
# ASX On Market                                      0.573
# ASX Continous Share                                0.725
# ASX Lit                                           -0.183
# Chi-X Lit                                         -0.594
# ASX Centre Point                                  -0.388
# Chi-X Dark                                        -0.129
# Reported to ASX                                    0.044
# Reported to Chi-X                                 -0.151
# Market                                            -0.218
# Lit + Dark                                         0.573
# Lit                                                0.645
# Reports                                            0.148
# CP Share                                          -0.137
# Row                                               -0.716
# Lit Trading - Vanilla                             -0.192
# Trade Registration                                 0.008
# Block Discovery                                   -0.090
# Undisclosed                                        0.045
# CentrePoint                                       -0.378
# Icebergs                                          -0.233
# Pref                                              -0.096
# UCP                                               -0.491
# CXA Market                                        -0.532
# Specials                                          -0.048
# NBBO Trade Report                                 -0.337
# Portfolio Specials                                -0.115
# Late Trades                                       -0.135
# Broker Pref                                        0.111
# 20-Day Realised SPI Vol                           -0.158
# MOC                                               -0.009
# Spread Differrential                              -0.519
# NBBO Trade Report.1                               -0.161
# %Sweep of Lit                                     -0.688
# Index Rebalance                                   -0.051
# ASX Lit Share (20 MA)                              0.976
# ASX Dark Share (20 MA)                             0.079
# ASX On Market.1                                    0.930
# ASX Continous Share (20 MA)                        1.000
# Number of Customer Meetings                       -0.043
# Average Meetings                                  -0.118
# Sensitive Announcments                            -0.084
#
#                              Number of Customer Meetings  Average Meetings  \
# ASX Lit Share                                     -0.045            -0.066
# ASX Dark Share                                    -0.070            -0.292
# ASX On Market                                     -0.082            -0.135
# ASX Continous Share                               -0.037            -0.068
# ASX Lit                                            0.128             0.192
# Chi-X Lit                                          0.141             0.196
# ASX Centre Point                                   0.063             0.002
# Chi-X Dark                                         0.166             0.268
# Reported to ASX                                    0.124            -0.025
# Reported to Chi-X                                  0.102             0.169
# Market                                             0.157             0.178
# Lit + Dark                                        -0.082            -0.134
# Lit                                               -0.045            -0.066
# Reports                                            0.004            -0.176
# CP Share                                          -0.140            -0.317
# Row                                                0.059             0.152
# Lit Trading - Vanilla                              0.154             0.210
# Trade Registration                                 0.128            -0.012
# Block Discovery                                    0.033             0.084
# Undisclosed                                        0.084            -0.015
# CentrePoint                                        0.068             0.004
# Icebergs                                          -0.005            -0.138
# Pref                                               0.082             0.015
# UCP                                                0.063             0.172
# CXA Market                                         0.158             0.229
# Specials                                           0.092             0.127
# NBBO Trade Report                                  0.152             0.188
# Portfolio Specials                                 0.026             0.100
# Late Trades                                       -0.005            -0.034
# Broker Pref                                        0.046             0.037
# 20-Day Realised SPI Vol                            0.141             0.238
# MOC                                               -0.034             0.087
# Spread Differrential                               0.035             0.016
# NBBO Trade Report.1                                0.037             0.108
# %Sweep of Lit                                     -0.119            -0.329
# Index Rebalance                                   -0.015             0.046
# ASX Lit Share (20 MA)                             -0.076            -0.142
# ASX Dark Share (20 MA)                            -0.081            -0.255
# ASX On Market.1                                   -0.130            -0.254
# ASX Continous Share (20 MA)                       -0.043            -0.118
# Number of Customer Meetings                        1.000             0.304
# Average Meetings                                   0.304             1.000
# Sensitive Announcments                             0.028            -0.039
#
#                              Sensitive Announcments
# ASX Lit Share                                 0.018
# ASX Dark Share                                0.037
# ASX On Market                                 0.042
# ASX Continous Share                          -0.035
# ASX Lit                                       0.112
# Chi-X Lit                                     0.084
# ASX Centre Point                              0.074
# Chi-X Dark                                   -0.001
# Reported to ASX                               0.075
# Reported to Chi-X                             0.048
# Market                                        0.115
# Lit + Dark                                    0.042
# Lit                                           0.018
# Reports                                       0.047
# CP Share                                      0.091
# Row                                          -0.002
# Lit Trading - Vanilla                         0.084
# Trade Registration                            0.074
# Block Discovery                               0.105
# Undisclosed                                   0.005
# CentrePoint                                   0.075
# Icebergs                                      0.105
# Pref                                          0.042
# UCP                                           0.003
# CXA Market                                    0.070
# Specials                                      0.053
# NBBO Trade Report                             0.064
# Portfolio Specials                            0.002
# Late Trades                                   0.007
# Broker Pref                                  -0.012
# 20-Day Realised SPI Vol                      -0.092
# MOC                                           0.005
# Spread Differrential                          0.083
# NBBO Trade Report.1                           0.023
# %Sweep of Lit                                 0.048
# Index Rebalance                              -0.029
# ASX Lit Share (20 MA)                        -0.104
# ASX Dark Share (20 MA)                        0.022
# ASX On Market.1                              -0.096
# ASX Continous Share (20 MA)                  -0.084
# Number of Customer Meetings                   0.028
# Average Meetings                             -0.039
# Sensitive Announcments                        1.000
#
# [43 rows x 43 columns]

# %%
# Project, bring in the file for analysis
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics
from sklearn import preprocessing
from sklearn.linear_model import RidgeCV
from sklearn import tree
from sklearn.cross_validation import cross_val_score
from sklearn.grid_search import GridSearchCV


pd.set_option('display.float_format', lambda x: '%.3f' % x)

xl = pd.ExcelFile("Project_Data.xlsx")
xl.sheet_names
df = xl.parse("Sheet1")

#preview of the raw data and return the column names
df.head()
df.columns
# examine to see if there are any null rows
df.isnull().sum()
#there are rows with null data, let us remove these rows
df = df.dropna()
# we have 547 rows of data left, enough for the regression. the dataframe has been cleaned.
df.count()

#drop columns which have the dates
df = df.drop('Date', axis=1)
df = df.drop('Date.1', axis=1)

df.columns
#The data is all in differrent units: percentages, raw numbers, $'s, basis points. 
#If we want to analyse the relative effects of each independent variable on the dependent variables, 
#we'll need to normalise all the data.
# Out:
# Index([u'ASX Lit Share', u'ASX Dark Share', u'ASX On Market',
#        u'ASX Continous Share', u'ASX Lit', u'Chi-X Lit', u'ASX Centre Point',
#        u'Chi-X Dark', u'Reported to ASX', u'Reported to Chi-X', u'Market',
#        u'Lit + Dark', u'Lit', u'Reports', u'CP Share', u'Row',
#        u'Lit Trading - Vanilla', u'Trade Registration', u'Block Discovery',
#        u'Undisclosed', u'CentrePoint', u'Icebergs', u'Pref', u'UCP',
#        u'CXA Market', u'Specials', u'NBBO Trade Report', u'Portfolio Specials',
#        u'Late Trades', u'Broker Pref', u'20-Day Realised SPI Vol', u'MOC',
#        u'Spread Differrential', u'NBBO Trade Report.1', u'%Sweep of Lit',
#        u'Index Rebalance', u'ASX Lit Share (20 MA)', u'ASX Dark Share (20 MA)',
#        u'ASX On Market.1', u'ASX Continous Share (20 MA)',
#        u'Number of Customer Meetings', u'Average Meetings',
#        u'Sensitive Announcments'],
#       dtype='object')

# %%
# the first regression we will look at is for the ASX Lit Market Share. For this, we will focus on the following columns of our raw dataset

#'ASX Lit Share', 'Lit Trading - Vanilla', 'Block Discovery', 'Undisclosed', 'Icebergs', 'Late Trades', '20-Day Realised SPI Vol', 'MOC', 'Spread Differrential', '%Sweep of Lit', 'Index Rebalance', u'ASX Lit Share (20 MA)', 'Average Meetings'  

dfLitShare = df[['ASX Lit Share', 'Chi-X Lit','ASX Centre Point',
       'Chi-X Dark', 'Reported to ASX', 'Reported to Chi-X',
       'Lit Trading - Vanilla', 'Block Discovery',
       'Undisclosed', 'CentrePoint', 'Icebergs', 'Pref', 'UCP',
       'Late Trades', 'Broker Pref', '20-Day Realised SPI Vol', 'MOC',
       'Spread Differrential', 'NBBO Trade Report.1', '%Sweep of Lit',
       'Index Rebalance', 'ASX Dark Share (20 MA)']]
#['ASX Lit Share', 'Lit Trading - Vanilla', 'Block Discovery', '20-Day Realised SPI Vol', 'Spread Differrential', '%Sweep of Lit', 'Index Rebalance', u'ASX Lit Share (20 MA)']]
dfLitShare

#The data is all in differrent units: percentages, raw numbers, $'s, basis points. 
#If we want to analyse the relative effects of each independent variable on the dependent variables, 
#we'll need to normalise all the data.

std_scale = preprocessing.StandardScaler().fit(dfLitShare)
dfLitShare_std = std_scale.transform(dfLitShare)

ColumnNames = ['ASXLitShare', 'Chi-X Lit','ASX Centre Point',
       'Chi-X Dark', 'Reported to ASX', 'Reported to Chi-X',
       'Lit Trading - Vanilla', 'Block Discovery',
       'Undisclosed', 'CentrePoint', 'Icebergs', 'Pref', 'UCP',
       'Late Trades', 'Broker Pref', '20-Day Realised SPI Vol', 'MOC',
       'Spread Differrential', 'NBBO Trade Report.1', '%Sweep of Lit',
       'Index Rebalance', 'ASX Dark Share (20 MA)']

dfLitShare_std = pd.DataFrame(dfLitShare_std, columns = ColumnNames) 
dfLitShare_std

#none of the independent variables look extremely correllated so we donot have to drop any independent variables
dfLitShare_std.corr()

#plot the data to see how it looks
#pd.scatter_matrix(dfLitShare_std, figsize=(15,15))
#plt.show()

#dfLitShare_std.describe()

#let us start the regression. We have chosen Lasso Ridge & Decision Trees for our regression. For those features which are
#irrellevant, we want the coefficients to be 0 rather than very close to zero like ridge regression

X = dfLitShare_std.iloc[:, 1:] #selection of columns, all the columns except the last one.
y = dfLitShare_std.iloc[:,0]


from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)


#use LassoCV to select best alpha, 100 partitions of the data

from sklearn.linear_model import LassoCV
alpha_range = 0.01**np.arange(-3, 3)
lascv = LassoCV(normalize=True, alphas=alpha_range, cv =50)
lascv.fit(X_train, y_train)
lascv.alpha_
lascv.coef_
preds = lascv.predict(X_test)
#print lascv.coef_
print 'RMSE (Lasso CV reg.) =', np.sqrt(metrics.mean_squared_error(y_test, preds))
print ('')
print pd.DataFrame(zip(X_train.columns, lascv.coef_)).sort_values(by=1, ascending=False)
print ('')

#use RidgeCV to select best alpha, 100 partitions of the data

alpha_range = 10.**np.arange(-3, 3)
#CV = indicates cross validation
rregcv = RidgeCV(normalize=True, scoring='mean_squared_error', alphas=alpha_range, cv =50)
rregcv.fit(X_train, y_train)
#print rregcv.coef_
rregcv.alpha_
preds = rregcv.predict(X_test)
print 'RMSE (Ridge CV reg.) =', np.sqrt(metrics.mean_squared_error(y_test, preds))
print ('')
print pd.DataFrame(zip(X_train.columns, rregcv.coef_)).sort_values(by=1, ascending=False)
print ('')


#Decision Tree

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)
rtree = tree.DecisionTreeRegressor()
rtree.fit(X_train, y_train)
scores = cross_val_score(rtree, X, y, cv=50, scoring='mean_squared_error')
mse_scores = scores


print 'RMSE (Decision Tree) =', mse_scores.mean()
print ('')
features = X_train.columns.tolist()
print pd.DataFrame(zip(features, rtree.feature_importances_)).sort_values(by=1, ascending=False)
print ('')


#'ASX Lit Share', 'ASX Dark Share', 'ASX On Market',
#       'ASX Continous Share', 'ASX Lit', 'Chi-X Lit', 'ASX Centre Point',
#       'Chi-X Dark', 'Reported to ASX', 'Reported to Chi-X', 'Market',
#       'Lit + Dark', 'Lit', 'Reports', 'CP Share', 'Row',
#       'Lit Trading - Vanilla', 'Trade Registration', 'Block Discovery',
#       'Undisclosed', 'CentrePoint', 'Icebergs', 'Pref', 'UCP',
#       'CXA Market', 'Specials', 'NBBO Trade Report', 'Portfolio Specials',
#       'Late Trades', 'Broker Pref', '20-Day Realised SPI Vol', 'MOC',
#       'Spread Differrential', 'NBBO Trade Report.1', '%Sweep of Lit',
#       'Index Rebalance', 'ASX Lit Share (20 MA)', 'ASX Dark Share (20 MA)'
# Out:
# RMSE (Lasso CV reg.) = 0.259561518996
#
#                           0      1
# 5     Lit Trading - Vanilla  0.896
# 6           Block Discovery  0.438
# 20   ASX Dark Share (20 MA)  0.059
# 11                      UCP  0.028
# 14  20-Day Realised SPI Vol  0.025
# 4         Reported to Chi-X  0.015
# 17      NBBO Trade Report.1  0.012
# 1          ASX Centre Point  0.007
# 12              Late Trades  0.006
# 8               CentrePoint  0.001
# 13              Broker Pref  0.000
# 10                     Pref  0.000
# 3           Reported to ASX  0.000
# 15                      MOC -0.000
# 2                Chi-X Dark -0.004
# 9                  Icebergs -0.008
# 7               Undisclosed -0.015
# 19          Index Rebalance -0.017
# 18            %Sweep of Lit -0.035
# 16     Spread Differrential -0.056
# 0                 Chi-X Lit -1.354
#
# RMSE (Ridge CV reg.) = 0.259827457071
#
#                           0      1
# 5     Lit Trading - Vanilla  0.886
# 6           Block Discovery  0.439
# 20   ASX Dark Share (20 MA)  0.064
# 14  20-Day Realised SPI Vol  0.033
# 11                      UCP  0.032
# 4         Reported to Chi-X  0.018
# 17      NBBO Trade Report.1  0.012
# 1          ASX Centre Point  0.010
# 8               CentrePoint  0.009
# 12              Late Trades  0.008
# 13              Broker Pref  0.007
# 10                     Pref  0.000
# 3           Reported to ASX -0.001
# 15                      MOC -0.002
# 9                  Icebergs -0.011
# 2                Chi-X Dark -0.015
# 7               Undisclosed -0.018
# 19          Index Rebalance -0.018
# 18            %Sweep of Lit -0.048
# 16     Spread Differrential -0.060
# 0                 Chi-X Lit -1.340
#
# RMSE (Decision Tree) = -0.397733222188
#
#                           0     1
# 18            %Sweep of Lit 0.265
# 6           Block Discovery 0.260
# 16     Spread Differrential 0.154
# 0                 Chi-X Lit 0.123
# 5     Lit Trading - Vanilla 0.068
# 13              Broker Pref 0.018
# 10                     Pref 0.015
# 14  20-Day Realised SPI Vol 0.015
# 9                  Icebergs 0.012
# 3           Reported to ASX 0.011
# 11                      UCP 0.010
# 7               Undisclosed 0.009
# 4         Reported to Chi-X 0.009
# 2                Chi-X Dark 0.008
# 20   ASX Dark Share (20 MA) 0.006
# 12              Late Trades 0.006
# 15                      MOC 0.004
# 1          ASX Centre Point 0.003
# 17      NBBO Trade Report.1 0.003
# 8               CentrePoint 0.001
# 19          Index Rebalance 0.000
